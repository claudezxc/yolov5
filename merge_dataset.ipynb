# %% [markdown]
# # Create Directories

# %%
# !mkdir -p /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/train/images
# !mkdir -p /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/train/labels
# !mkdir -p /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/test/images
# !mkdir -p /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/test/labels
# !mkdir -p /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/valid/images
# !mkdir -p /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/valid/labels

# %% [markdown]
# # Copy images and labels from the first dataset

# %%
# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Acne-Detection-V1-1/train/images/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/train/images/
# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Acne-Detection-V1-1/train/labels/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/train/labels/

# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Acne-Detection-V1-1/test/images/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/test/images/
# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Acne-Detection-V1-1/test/labels/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/test/labels/

# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Acne-Detection-V1-1/valid/images/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/valid/images/
# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Acne-Detection-V1-1/valid/labels/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/valid/labels/

# %% [markdown]
# # Copy images and labels from the second dataset

# %%
# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Skin-Problems-Detection-8/train/images/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/train/images/
# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Skin-Problems-Detection-8/train/labels/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/train/labels/

# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Skin-Problems-Detection-8/test/images/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/test/images/
# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Skin-Problems-Detection-8/test/labels/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/test/labels/

# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Skin-Problems-Detection-8/valid/images/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/valid/images/
# !cp /content/drive/MyDrive/project_folder/AcneClassification_Yolo/Skin-Problems-Detection-8/valid/labels/* /content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/valid/labels/

# %% [markdown]
# # Create or update data.yaml with selected classes

# %%
data_yaml_path = '/content/drive/MyDrive/project_folder/AcneClassification_Yolo/merged_dataset/data.yaml'

with open(data_yaml_path, 'w') as f:
    f.write('train: ./filtered_train/images\n')
    f.write('val: ./valid/images\n')
    f.write('test: ./test/images\n')
    f.write('\nnames:\n')
    f.write('  - cyst\n')
    f.write('  - nodule\n')
    f.write('  - papule\n')
    f.write('  - pustule\n')
    f.write('  - comedone\n')
    f.write('  - whitehead\n')
    f.write('  - blackhead\n')
